# %%
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
iris = load_iris()
X, y = iris.data, iris.target
iris_df = pd.DataFrame(iris.data, columns=iris.feature_names)

# Now you can access the columns as shown above
sepal_length = iris_df['sepal length (cm)']
sepal_width = iris_df['sepal width (cm)']
petal_length = iris_df['petal length (cm)']
petal_width = iris_df['petal width (cm)']


# Calculate the covariance matrix
cov_matrix = iris_df.cov()
print("covariance matrix")
print(cov_matrix)

# Calculate covariance between sepal length and sepal width
covariance_matrix = np.cov(sepal_length, sepal_width)
covariance_sepal_length_width = covariance_matrix[0, 1]

covariance_sepal_length_width

# Assuming iris_df is your DataFrame containing the Iris dataset
correlation_matrix = iris_df.corr()
print("Correlation matrix")
print(correlation_matrix)

plt.figure(figsize=(8, 5))
plt.scatter(iris_df['sepal length (cm)'], iris_df['sepal width (cm)'], color='blue', alpha=0.5)
plt.title('Sepal Length vs Sepal Width')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.grid(True)
plt.show()
# Out:
# covariance matrix
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           0.685694         -0.042434           1.274315
# sepal width (cm)           -0.042434          0.189979          -0.329656
# petal length (cm)           1.274315         -0.329656           3.116278
# petal width (cm)            0.516271         -0.121639           1.295609
#
#                    petal width (cm)
# sepal length (cm)          0.516271
# sepal width (cm)          -0.121639
# petal length (cm)          1.295609
# petal width (cm)           0.581006
# Correlation matrix
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.117570           0.871754
# sepal width (cm)           -0.117570          1.000000          -0.428440
# petal length (cm)           0.871754         -0.428440           1.000000
# petal width (cm)            0.817941         -0.366126           0.962865
# ...

# %% [markdown]
# Covariance between Sepal Length and Sepal Width: -0.0424
# Correlation Coefficient between Sepal Length and Sepal Width: -0.1176
# The negative covariance and correlation coefficient values indicate a slight inverse relationship between sepal length and sepal width; as one increases, the other tends to slightly decrease. However, the correlation coefficient is close to 0, suggesting that this relationship is very weak.
#
# The scatter plot visualizes the relationship between sepal length and sepal width, showing that there isn't a strong linear trend between these two features. The spread of the points suggests variability in the relationship, with no clear pattern indicating a strong correlation
